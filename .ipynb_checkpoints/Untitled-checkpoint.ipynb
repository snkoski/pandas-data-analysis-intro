# %%
import pandas as pd

# %%
players = pd.read_csv("npo_players.csv")

# %%
players.head()
# Out:
#    Unnamed: 0               Name  Year  Age Team Position  Games  \
# 0           0  Jonas Valanciunas  2013   20  TOR        C     62
# 1           1  Jonas Valanciunas  2014   21  TOR        C     81
# 2           2  Jonas Valanciunas  2015   22  TOR        C     80
# 3           3  Jonas Valanciunas  2016   23  TOR        C     60
# 4           4  Jonas Valanciunas  2017   24  TOR        C     80
#
#    Games Started  Minutes Per Game  Field Goals Per Game       ...         \
# 0             57              23.9                   3.3       ...
# 1             81              28.2                   4.4       ...
# 2             80              26.2                   4.7       ...
# 3             59              26.0                   5.1       ...
# 4             80              25.8                   4.9       ...
#
#    Free Throw Attempts Per Game  Free Throw Percent  \
# 0                           3.0               0.789
# 1                           3.2               0.762
# ...

# %%
players.set_index("Name", inplace=True)

# %%
players.head()
# Out:
#                    Unnamed: 0  Year  Age Team Position  Games  Games Started  \
# Name
# Jonas Valanciunas           0  2013   20  TOR        C     62             57
# Jonas Valanciunas           1  2014   21  TOR        C     81             81
# Jonas Valanciunas           2  2015   22  TOR        C     80             80
# Jonas Valanciunas           3  2016   23  TOR        C     60             59
# Jonas Valanciunas           4  2017   24  TOR        C     80             80
#
#                    Minutes Per Game  Field Goals Per Game  \
# Name
# Jonas Valanciunas              23.9                   3.3
# Jonas Valanciunas              28.2                   4.4
# Jonas Valanciunas              26.2                   4.7
# Jonas Valanciunas              26.0                   5.1
# Jonas Valanciunas              25.8                   4.9
#
#                    Field Goal Attempts Per Game       ...         \
# Name                                                  ...
# ...

# %%
del players["Unnamed: 0"]

# %%
players.head()
# Out:
#                    Year  Age Team Position  Games  Games Started  \
# Name
# Jonas Valanciunas  2013   20  TOR        C     62             57
# Jonas Valanciunas  2014   21  TOR        C     81             81
# Jonas Valanciunas  2015   22  TOR        C     80             80
# Jonas Valanciunas  2016   23  TOR        C     60             59
# Jonas Valanciunas  2017   24  TOR        C     80             80
#
#                    Minutes Per Game  Field Goals Per Game  \
# Name
# Jonas Valanciunas              23.9                   3.3
# Jonas Valanciunas              28.2                   4.4
# Jonas Valanciunas              26.2                   4.7
# Jonas Valanciunas              26.0                   5.1
# Jonas Valanciunas              25.8                   4.9
#
#                    Field Goal Attempts Per Game  Field Goal Percent  \
# Name
# Jonas Valanciunas                           5.9               0.557
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, Jonas Valanciunas to Quincy Acy
# Data columns (total 28 columns):
# Year                                    2343 non-null int64
# Age                                     2343 non-null int64
# Team                                    2343 non-null object
# Position                                2342 non-null object
# Games                                   2343 non-null int64
# Games Started                           2343 non-null int64
# Minutes Per Game                        2343 non-null float64
# Field Goals Per Game                    2343 non-null float64
# Field Goal Attempts Per Game            2343 non-null float64
# Field Goal Percent                      2333 non-null float64
# 3-Point Field Goals Per Game            2343 non-null float64
# 3-Point Field Goal Attempts Per Game    2343 non-null float64
# 3-Point Field Goal Percent              2186 non-null float64
# ...

# %%
players.sort_index()
# Out:
#                  Year  Age Team Position  Games  Games Started  \
# Name
# Aaron Gordon     2016   20  ORL       PF     78             37
# Aaron Gordon     2015   19  ORL       PF     47              8
# Aaron Gordon     2017   21  ORL       SF     80             72
# Aaron Gordon     2018   22  ORL       PF     58             57
# Aaron Gordon     2019   23  ORL       PF     39             39
# Aaron Holiday    2019   22  IND       PG     23              0
# Abdel Nader      2019   25  OKC       SF     22              1
# Abdel Nader      2018   24  BOS       SF     48              1
# Al Horford       2011   24  ATL        C     77             77
# Al Horford       2010   23  ATL        C     81             81
# Al Horford       2009   22  ATL        C     67             67
# Al Horford       2008   21  ATL        C     81             77
# Al Horford       2013   26  ATL        C     74             74
# Al Horford       2015   28  ATL        C     76             76
# ...

# %%
players["Year"].nunique()
# Out:
# 21

# %%
for col in players.columns:
    print(col, players[col].nunique())
# Out:
# Year 21
# Age 25
# Team 36
# Position 14
# Games 82
# Games Started 83
# Minutes Per Game 373
# Field Goals Per Game 106
# Field Goal Attempts Per Game 215
# Field Goal Percent 345
# 3-Point Field Goals Per Game 43
# 3-Point Field Goal Attempts Per Game 92
# 3-Point Field Goal Percent 304
# 2-Point Field Goals Per Game 97
# 2-Point Field Goal Attempts Per Game 185
# 2-Point Field Goal Percent 340
# Effective Field Goal Percent 319
# Free Throws Per Game 89
# Free Throw Attempts Per Game 108
# Free Throw Percent 436
# Offensive Rebounds Per Game 52
# Defensive Rebounds Per Game 106
# Assists Per Game 104
# Steals Per Game 28
# Blocks Per Game 32
# Turnovers Per Game 50
# Personal Fouls Per Game 42
# Points Per Game 284

# %%
players["Age"]
# Out:
# Name
# Jonas Valanciunas     20
# Jonas Valanciunas     21
# Jonas Valanciunas     22
# Jonas Valanciunas     23
# Jonas Valanciunas     24
# Jonas Valanciunas     25
# Jonas Valanciunas     26
# Delon Wright          23
# Delon Wright          24
# Delon Wright          25
# Delon Wright          26
# Kawhi Leonard         20
# Kawhi Leonard         21
# Kawhi Leonard         22
# Kawhi Leonard         23
# Kawhi Leonard         24
# Kawhi Leonard         25
# Kawhi Leonard         26
# Kawhi Leonard         27
# Danny Green           22
# Danny Green           23
# Danny Green           24
# Danny Green           25
# Danny Green           26
# Danny Green           27
# Danny Green           28
# Danny Green           29
# Danny Green           30
# Danny Green           31
# Malachi Richardson    21
#                       ..
# Elie Okobo            21
# De'Anthony Melton     20
# Jamal Crawford        20
# Jamal Crawford        21
# Jamal Crawford        22
# ...

# %%
for col in players.columns:
    if players[col].nunique() <= 36:
        players[col] = players[col].astype("category")

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, Jonas Valanciunas to Quincy Acy
# Data columns (total 28 columns):
# Year                                    2343 non-null category
# Age                                     2343 non-null category
# Team                                    2343 non-null category
# Position                                2342 non-null category
# Games                                   2343 non-null int64
# Games Started                           2343 non-null int64
# Minutes Per Game                        2343 non-null float64
# Field Goals Per Game                    2343 non-null float64
# Field Goal Attempts Per Game            2343 non-null float64
# Field Goal Percent                      2333 non-null float64
# 3-Point Field Goals Per Game            2343 non-null float64
# 3-Point Field Goal Attempts Per Game    2343 non-null float64
# 3-Point Field Goal Percent              2186 non-null float64
# ...
