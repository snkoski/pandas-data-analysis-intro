# %%
import pandas as pd

# %% [markdown]
# # Create A Series Object From A Python List

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Ice"]

pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3           Ice
# dtype: object

# %%
lottery = [4, 8, 15, 16, 23, 42]

pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
registrations = [True, True, False, True, False]

pd.Series(registrations)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# # Create A Series Object From A Python Dictionary

# %%
webster = {"Aardvark" : "An animal",
           "Banana" : "A fruit",
           "Cyan" : "A color"}

pd.Series(webster)
# Out:
# Aardvark    An animal
# Banana        A fruit
# Cyan          A color
# dtype: object

# %% [markdown]
# # Intro To Attributes

# %%
about_me = ["Smart", "Handsome", "Swag", "Ballin", "Humble"]
s = pd.Series(about_me)
s
# Out:
# 0       Smart
# 1    Handsome
# 2        Swag
# 3      Ballin
# 4      Humble
# dtype: object

# %%
s.values
# Out:
# array(['Smart', 'Handsome', 'Swag', 'Ballin', 'Humble'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# # Intro To Methods

# %%
prices = [2.99, 4.45, 1.36]
s = pd.Series(prices)
s
# Out:
# 0    2.99
# 1    4.45
# 2    1.36
# dtype: float64

# %%
s.sum()
# Out:
# 8.8

# %%
s.product()
# Out:
# 18.095480000000006

# %%
s.mean()
# Out:
# 2.9333333333333336

# %%
df = pd.read_csv('npo_players.csv', index_col='Year')

# %%
df.head()
# Out:
#       Unnamed: 0               Name  Age Team Position  Games  Games Started  \
# Year
# 2013           0  Jonas Valanciunas   20  TOR        C     62             57
# 2014           1  Jonas Valanciunas   21  TOR        C     81             81
# 2015           2  Jonas Valanciunas   22  TOR        C     80             80
# 2016           3  Jonas Valanciunas   23  TOR        C     60             59
# 2017           4  Jonas Valanciunas   24  TOR        C     80             80
#
#       Minutes Per Game  Field Goals Per Game  Field Goal Attempts Per Game  \
# Year
# 2013              23.9                   3.3                           5.9
# 2014              28.2                   4.4                           8.3
# 2015              26.2                   4.7                           8.2
# 2016              26.0                   5.1                           8.9
# 2017              25.8                   4.9                           8.8
#
# ...

# %%
sorted_year = df.drop(columns=['Unnamed: 0'])

# %%
sorted_by_team = sorted_year.sort_values(by='Team')

# %%
sorted_by_team.columns
# Out:
# Index(['Name', 'Age', 'Team', 'Position', 'Games', 'Games Started',
#        'Minutes Per Game', 'Field Goals Per Game',
#        'Field Goal Attempts Per Game', 'Field Goal Percent',
#        '3-Point Field Goals Per Game', '3-Point Field Goal Attempts Per Game',
#        '3-Point Field Goal Percent', '2-Point Field Goals Per Game',
#        '2-Point Field Goal Attempts Per Game', '2-Point Field Goal Percent',
#        'Effective Field Goal Percent', 'Free Throws Per Game',
#        'Free Throw Attempts Per Game', 'Free Throw Percent',
#        'Offensive Rebounds Per Game', 'Defensive Rebounds Per Game',
#        'Assists Per Game', 'Steals Per Game', 'Blocks Per Game',
#        'Turnovers Per Game', 'Personal Fouls Per Game', 'Points Per Game'],
#       dtype='object')

# %%
q = pd.read_csv('npo_players.csv')

# %%
desired = q['Year'] == 2018

# %%
team_year = q[desired].sort_values(by="Team")

# %%
team_was = team_year[team_year['Team'] == 'WAS']

# %%
team_was
# Out:
#       Unnamed: 0              Name  Year  Age Team Position  Games  \
# 2282        2282   Kelly Oubre Jr.  2018   22  WAS       SF     81
# 1388        1388        Mike Scott  2018   29  WAS       PF     76
# 683          683   Markieff Morris  2018   28  WAS       PF     73
# 692          692         John Wall  2018   27  WAS       PG     41
# 124          124       Jason Smith  2018   31  WAS        C     33
# 707          707       Ian Mahinmi  2018   31  WAS        C     77
# 710          710  Tomas Satoransky  2018   26  WAS       SG     73
# 1321        1321     Marcin Gortat  2018   33  WAS        C     82
# 752          752    Devin Robinson  2018   22  WAS       SF      1
# 723          723       Otto Porter  2018   24  WAS       SF     77
# 717          717      Bradley Beal  2018   24  WAS       SG     82
#
#       Games Started  Minutes Per Game  Field Goals Per Game       ...         \
# 2282             11              27.5                   3.9       ...
# ...

# %%
team_was.to_csv('was_2018.csv')

# %%
team_bos = team_year[team_year['Team'] == 'BOS']
team_bos
# Out:
#       Unnamed: 0                Name  Year  Age Team Position  Games  \
# 365          365          Al Horford  2018   31  BOS        C     72
# 381          381        Semi Ojeleye  2018   23  BOS       PF     73
# 341          341        Kyrie Irving  2018   25  BOS       PG     60
# 1267        1267         Abdel Nader  2018   24  BOS       SF     48
# 383          383  Guerschon Yabusele  2018   22  BOS       PF     33
# 385          385        Daniel Theis  2018   25  BOS        C     63
# 394          394         Aron Baynes  2018   31  BOS        C     81
# 399          399        Marcus Smart  2018   23  BOS       SG     54
# 368          368        Jaylen Brown  2018   21  BOS       SG     70
# 349          349       Marcus Morris  2018   28  BOS       PF     54
# 1122        1122       Isaiah Thomas  2018   27  BOS       PG     76
# 353          353        Terry Rozier  2018   23  BOS       PG     80
# 370          370        Jayson Tatum  2018   19  BOS       SF     80
# ...

# %%
team_bos.to_csv('bos_2018.csv')
